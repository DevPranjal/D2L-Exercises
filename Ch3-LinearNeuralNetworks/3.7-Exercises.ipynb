# %% [markdown]
# # 3.7 Concise Implementation of Softmax Regression

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Q1. Try adjusting the hyperparameters, such as the batch size, number of epochs, and learning rate, to see what the results are.

# %%
import torch
from d2l import torch as d2l
from torch import nn

# %%
net = nn.Sequential(nn.Flatten(), nn.Linear(784, 10))
loss = nn.CrossEntropyLoss()
trainer = torch.optim.SGD(net.parameters(), lr=0.1)

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size = 256
lr = 0.1
num_epochs = 10
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %%
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size = 256
lr = 0.1
num_epochs = 50
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %%
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size = 512
lr = 0.01
num_epochs = 10
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %%
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %% [markdown]
# ### Q2. Increase the number of epochs for training. Why might the test accuracy decrease after a while? How could we fix this?

# %% [markdown]
# From the above example we can see a decrease in test accuracy as the number of epochs trained increases. This is due to overfitting of the model to the training data, hence its accuracy on the test data decreases.
#
# Overfitting can be avoided by various techniques. Some techniques have been discussed in section 4.5 (Weight Decay) and section 4.6 (Dropout) of this book. The general idea behind these techniques is to decrease the model complexity.
